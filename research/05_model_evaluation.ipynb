# %%
import os

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'c:\\Users\\kesha\\OneDrive\\Desktop\\MLOps\\winery'

# %%
os.environ["MLFLOW_TRACKING_URI"]="https://dagshub.com/AshleshaNemade/winery.mlflow"
os.environ["MLFLOW_TRACKING_USERNAME"]="AshleshaNemade"
os.environ["MLFLOW_TRACKING_PASSWORD"]="d64fffa456a3f4b7bfaa976259b77c0bef6dc2a6"
